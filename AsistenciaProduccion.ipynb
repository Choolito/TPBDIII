-- %% [markdown]
-- # [dbo].[Articulo]

-- %%
USE [AsistenciaProduccion]
GO

-- %%
/****** Object:  Table [dbo].[Articulo]    Script Date: 14/6/2024 13:40:58 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Articulo](
	[idArticulo] [int] NOT NULL,
	[descripcion] [varchar](max) NULL,
	[Tiempo_fabricacion] [int] NULL,
	[costototal] [decimal](10, 2) NULL,
	[unidadMedida] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[idArticulo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MateriaPrima]

-- %%
/****** Object:  Table [dbo].[MateriaPrima]    Script Date: 14/6/2024 13:40:58 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MateriaPrima](
	[idMateriaPrima] [int] NOT NULL,
	[descripcion] [varchar](200) NULL,
	[costo] [decimal](10, 2) NULL,
	[unidadMedida] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[idMateriaPrima] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrdenFabricacion]

-- %%
/****** Object:  Table [dbo].[OrdenFabricacion]    Script Date: 14/6/2024 13:40:58 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrdenFabricacion](
	[ldOrden] [int] NOT NULL,
	[idPlanta] [int] NULL,
	[FechaHoraInicioplan] [datetime] NULL,
	[FechaHoraFinPlan] [datetime] NULL,
	[FechaHoraInicioReal] [datetime] NULL,
	[FechaHoraFinReal] [datetime] NULL,
	[idArticulo] [int] NULL,
	[cantidadPlanificada] [int] NULL,
	[cantidadRealizada] [int] NULL,
	[legajoEmpleadoResponsable] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ldOrden] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantaFabricacion]

-- %%
/****** Object:  Table [dbo].[PlantaFabricacion]    Script Date: 14/6/2024 13:40:58 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantaFabricacion](
	[idPlanta] [int] NOT NULL,
	[nombre] [varchar](100) NULL,
	[direccion] [varchar](200) NULL,
	[codigopostal] [varchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[idPlanta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RecetaProduccion]

-- %%
/****** Object:  Table [dbo].[RecetaProduccion]    Script Date: 14/6/2024 13:40:58 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RecetaProduccion](
	[IdArticulo] [int] NOT NULL,
	[idMateriaPrima] [int] NOT NULL,
	[Cantidad] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdArticulo] ASC,
	[idMateriaPrima] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Articulo]

-- %%
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (1, N'mattis', 7, CAST(74424.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (2, N'mi', 17, CAST(50558.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (3, N'quisque', 5, CAST(94674.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (4, N'id', 22, CAST(17911.00 AS Decimal(10, 2)), N'ft')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (5, N'purus', 20, CAST(88901.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (6, N'nisl', 2, CAST(21204.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (7, N'diam', 22, CAST(31272.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (8, N'bibendum', 3, CAST(12330.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (9, N'donec', 10, CAST(76323.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (10, N'sit', 3, CAST(20620.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (11, N'elit', 3, CAST(85972.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (12, N'velit', 14, CAST(57071.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (13, N'in', 23, CAST(20263.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (14, N'proin', 14, CAST(32871.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (15, N'nunc', 4, CAST(80431.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (16, N'quis', 2, CAST(11760.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (17, N'nisi', 11, CAST(77489.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (18, N'fusce', 13, CAST(17705.00 AS Decimal(10, 2)), N'ft')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (19, N'libero', 2, CAST(68210.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (20, N'ligula', 2, CAST(25712.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (21, N'interdum', 12, CAST(12523.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (22, N'justo', 9, CAST(29106.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (23, N'interdum', 21, CAST(59910.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (24, N'eleifend', 20, CAST(90229.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (25, N'in', 13, CAST(11505.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (26, N'hac', 20, CAST(14758.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (27, N'nulla', 4, CAST(68762.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (28, N'nulla', 12, CAST(41281.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (29, N'donec', 4, CAST(81500.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (30, N'eu', 1, CAST(50900.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (31, N'amet', 3, CAST(44018.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (32, N'praesent', 11, CAST(75909.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (33, N'aliquam', 5, CAST(82068.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (34, N'rutrum', 23, CAST(93797.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (35, N'sem', 6, CAST(61360.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (36, N'tristique', 12, CAST(24522.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (37, N'porta', 19, CAST(35499.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (38, N'montes', 15, CAST(86519.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (39, N'nibh', 9, CAST(50191.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (40, N'nullam', 9, CAST(27427.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (41, N'ligula', 8, CAST(42831.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (42, N'ridiculus', 11, CAST(57042.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (43, N'libero', 4, CAST(47253.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (44, N'justo', 23, CAST(29747.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (45, N'justo', 10, CAST(29203.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (46, N'donec', 18, CAST(86873.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (47, N'lorem', 12, CAST(61386.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (48, N'vestibulum', 1, CAST(31277.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (49, N'dolor', 23, CAST(75464.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[Articulo] ([idArticulo], [descripcion], [Tiempo_fabricacion], [costototal], [unidadMedida]) VALUES (50, N'diam', 17, CAST(65362.00 AS Decimal(10, 2)), N'in')
GO

-- %% [markdown]
-- # [dbo].[MateriaPrima]

-- %%
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (1, N'sed', CAST(42258.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (2, N'elit', CAST(11352.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (3, N'nullam', CAST(70396.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (4, N'tempor', CAST(95379.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (5, N'consectetuer', CAST(45325.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (6, N'lacinia', CAST(80219.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (7, N'maecenas', CAST(90998.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (8, N'justo', CAST(70986.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (9, N'hac', CAST(12320.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (10, N'justo', CAST(39218.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (11, N'justo', CAST(38774.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (12, N'aliquam', CAST(75408.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (13, N'vitae', CAST(98207.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (14, N'ullamcorper', CAST(96616.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (15, N'fermentum', CAST(20585.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (16, N'pede', CAST(77899.00 AS Decimal(10, 2)), N'ft')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (17, N'lorem', CAST(82576.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (18, N'sed', CAST(87316.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (19, N'aliquam', CAST(93203.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (20, N'molestie', CAST(52944.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (21, N'volutpat', CAST(67322.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (22, N'accumsan', CAST(24879.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (23, N'accumsan', CAST(21582.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (24, N'euismod', CAST(38137.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (25, N'pede', CAST(49628.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (26, N'amet', CAST(35245.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (27, N'eros', CAST(41038.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (28, N'iaculis', CAST(46847.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (29, N'vestibulum', CAST(32462.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (30, N'vel', CAST(53790.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (31, N'primis', CAST(23979.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (32, N'imperdiet', CAST(38844.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (33, N'orci', CAST(35624.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (34, N'in', CAST(17566.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (35, N'vestibulum', CAST(80803.00 AS Decimal(10, 2)), N'in')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (36, N'quam', CAST(59174.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (37, N'vitae', CAST(19981.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (38, N'mattis', CAST(49119.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (39, N'morbi', CAST(78248.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (40, N'magna', CAST(93028.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (41, N'posuere', CAST(41822.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (42, N'convallis', CAST(55645.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (43, N'nec', CAST(40527.00 AS Decimal(10, 2)), N'ft')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (44, N'et', CAST(29396.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (45, N'eget', CAST(48230.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (46, N'tempus', CAST(32503.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (47, N'sem', CAST(81278.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (48, N'pede', CAST(24334.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (49, N'praesent', CAST(20525.00 AS Decimal(10, 2)), N'pt')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (50, N'posuere', CAST(56102.00 AS Decimal(10, 2)), N'm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (51, N'luctus', CAST(51037.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (52, N'at', CAST(37316.00 AS Decimal(10, 2)), N'oz')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (53, N'venenatis', CAST(56266.00 AS Decimal(10, 2)), N'kg')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (54, N'orci', CAST(91761.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (55, N'egestas', CAST(48131.00 AS Decimal(10, 2)), N'gal')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (56, N'ante', CAST(87151.00 AS Decimal(10, 2)), N'ft')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (57, N'tellus', CAST(62983.00 AS Decimal(10, 2)), N'L')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (58, N'justo', CAST(90505.00 AS Decimal(10, 2)), N'lb')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (59, N'vel', CAST(26780.00 AS Decimal(10, 2)), N'cm')
INSERT [dbo].[MateriaPrima] ([idMateriaPrima], [descripcion], [costo], [unidadMedida]) VALUES (60, N'vestibulum', CAST(60000.00 AS Decimal(10, 2)), N'kg')
GO

-- %% [markdown]
-- # [dbo].[OrdenFabricacion]

-- %%
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (1, 8, CAST(N'2023-12-05T00:00:00.000' AS DateTime), CAST(N'2023-12-25T00:00:00.000' AS DateTime), CAST(N'2024-05-07T00:00:00.000' AS DateTime), CAST(N'2023-12-15T00:00:00.000' AS DateTime), 23, 3, 18, 171)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (2, 8, CAST(N'2023-11-17T00:00:00.000' AS DateTime), CAST(N'2024-01-19T00:00:00.000' AS DateTime), CAST(N'2023-12-29T00:00:00.000' AS DateTime), CAST(N'2023-08-21T00:00:00.000' AS DateTime), 46, 26, 14, 280)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (3, 8, CAST(N'2023-12-14T00:00:00.000' AS DateTime), CAST(N'2023-08-19T00:00:00.000' AS DateTime), CAST(N'2024-04-08T00:00:00.000' AS DateTime), CAST(N'2024-03-07T00:00:00.000' AS DateTime), 34, 14, 33, 156)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (4, 9, CAST(N'2023-10-26T00:00:00.000' AS DateTime), CAST(N'2024-01-14T00:00:00.000' AS DateTime), CAST(N'2024-04-06T00:00:00.000' AS DateTime), CAST(N'2024-03-13T00:00:00.000' AS DateTime), 43, 27, 4, 266)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (5, 3, CAST(N'2023-07-10T00:00:00.000' AS DateTime), CAST(N'2023-10-07T00:00:00.000' AS DateTime), CAST(N'2024-02-18T00:00:00.000' AS DateTime), CAST(N'2023-12-10T00:00:00.000' AS DateTime), 12, 7, 18, 338)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (6, 9, CAST(N'2023-10-13T00:00:00.000' AS DateTime), CAST(N'2024-03-27T00:00:00.000' AS DateTime), CAST(N'2023-11-18T00:00:00.000' AS DateTime), CAST(N'2023-09-22T00:00:00.000' AS DateTime), 26, 40, 29, 236)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (7, 9, CAST(N'2023-07-24T00:00:00.000' AS DateTime), CAST(N'2024-01-20T00:00:00.000' AS DateTime), CAST(N'2023-09-11T00:00:00.000' AS DateTime), CAST(N'2023-11-02T00:00:00.000' AS DateTime), 10, 7, 39, 178)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (8, 8, CAST(N'2024-05-03T00:00:00.000' AS DateTime), CAST(N'2023-10-07T00:00:00.000' AS DateTime), CAST(N'2023-08-20T00:00:00.000' AS DateTime), CAST(N'2023-08-19T00:00:00.000' AS DateTime), 16, 20, 17, 43)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (9, 2, CAST(N'2024-03-25T00:00:00.000' AS DateTime), CAST(N'2023-10-19T00:00:00.000' AS DateTime), CAST(N'2023-07-29T00:00:00.000' AS DateTime), CAST(N'2023-08-15T00:00:00.000' AS DateTime), 45, 1, 17, 180)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (10, 5, CAST(N'2024-02-14T00:00:00.000' AS DateTime), CAST(N'2024-05-10T00:00:00.000' AS DateTime), CAST(N'2023-07-12T00:00:00.000' AS DateTime), CAST(N'2023-10-27T00:00:00.000' AS DateTime), 40, 31, 48, 190)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (11, 8, CAST(N'2023-08-26T00:00:00.000' AS DateTime), CAST(N'2023-07-18T00:00:00.000' AS DateTime), CAST(N'2023-06-08T00:00:00.000' AS DateTime), CAST(N'2023-06-02T00:00:00.000' AS DateTime), 27, 3, 16, 102)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (12, 1, CAST(N'2024-04-30T00:00:00.000' AS DateTime), CAST(N'2024-05-06T00:00:00.000' AS DateTime), CAST(N'2023-10-02T00:00:00.000' AS DateTime), CAST(N'2023-06-24T00:00:00.000' AS DateTime), 34, 30, 36, 347)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (13, 2, CAST(N'2023-09-25T00:00:00.000' AS DateTime), CAST(N'2023-06-19T00:00:00.000' AS DateTime), CAST(N'2024-05-05T00:00:00.000' AS DateTime), CAST(N'2024-04-16T00:00:00.000' AS DateTime), 9, 47, 35, 180)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (14, 5, CAST(N'2024-05-23T00:00:00.000' AS DateTime), CAST(N'2023-09-07T00:00:00.000' AS DateTime), CAST(N'2024-02-07T00:00:00.000' AS DateTime), CAST(N'2024-04-01T00:00:00.000' AS DateTime), 33, 10, 27, 92)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (15, 7, CAST(N'2024-03-13T00:00:00.000' AS DateTime), CAST(N'2024-02-01T00:00:00.000' AS DateTime), CAST(N'2023-08-21T00:00:00.000' AS DateTime), CAST(N'2023-12-17T00:00:00.000' AS DateTime), 20, 22, 22, 107)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (16, 10, CAST(N'2024-03-19T00:00:00.000' AS DateTime), CAST(N'2023-10-29T00:00:00.000' AS DateTime), CAST(N'2024-03-28T00:00:00.000' AS DateTime), CAST(N'2024-04-06T00:00:00.000' AS DateTime), 50, 41, 39, 112)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (17, 3, CAST(N'2023-07-21T00:00:00.000' AS DateTime), CAST(N'2023-08-09T00:00:00.000' AS DateTime), CAST(N'2024-04-12T00:00:00.000' AS DateTime), CAST(N'2024-01-01T00:00:00.000' AS DateTime), 11, 35, 16, 355)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (18, 9, CAST(N'2024-03-31T00:00:00.000' AS DateTime), CAST(N'2024-02-19T00:00:00.000' AS DateTime), CAST(N'2023-12-15T00:00:00.000' AS DateTime), CAST(N'2023-10-06T00:00:00.000' AS DateTime), 7, 21, 8, 344)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (19, 10, CAST(N'2023-07-20T00:00:00.000' AS DateTime), CAST(N'2024-03-30T00:00:00.000' AS DateTime), CAST(N'2024-04-18T00:00:00.000' AS DateTime), CAST(N'2024-03-13T00:00:00.000' AS DateTime), 28, 45, 41, 271)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (20, 2, CAST(N'2023-12-15T00:00:00.000' AS DateTime), CAST(N'2023-09-17T00:00:00.000' AS DateTime), CAST(N'2024-01-20T00:00:00.000' AS DateTime), CAST(N'2024-04-28T00:00:00.000' AS DateTime), 50, 12, 17, 88)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (21, 8, CAST(N'2024-01-03T00:00:00.000' AS DateTime), CAST(N'2023-10-12T00:00:00.000' AS DateTime), CAST(N'2023-09-01T00:00:00.000' AS DateTime), CAST(N'2024-01-26T00:00:00.000' AS DateTime), 32, 19, 13, 230)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (22, 7, CAST(N'2024-03-08T00:00:00.000' AS DateTime), CAST(N'2024-03-27T00:00:00.000' AS DateTime), CAST(N'2024-05-14T00:00:00.000' AS DateTime), CAST(N'2023-06-09T00:00:00.000' AS DateTime), 5, 21, 5, 179)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (23, 9, CAST(N'2024-02-10T00:00:00.000' AS DateTime), CAST(N'2023-09-29T00:00:00.000' AS DateTime), CAST(N'2023-12-13T00:00:00.000' AS DateTime), CAST(N'2024-01-13T00:00:00.000' AS DateTime), 3, 7, 37, 13)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (24, 1, CAST(N'2023-06-02T00:00:00.000' AS DateTime), CAST(N'2024-04-28T00:00:00.000' AS DateTime), CAST(N'2024-02-23T00:00:00.000' AS DateTime), CAST(N'2023-12-29T00:00:00.000' AS DateTime), 28, 40, 4, 322)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (25, 2, CAST(N'2023-06-25T00:00:00.000' AS DateTime), CAST(N'2023-09-24T00:00:00.000' AS DateTime), CAST(N'2024-02-27T00:00:00.000' AS DateTime), CAST(N'2023-10-10T00:00:00.000' AS DateTime), 20, 32, 45, 244)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (26, 2, CAST(N'2023-08-19T00:00:00.000' AS DateTime), CAST(N'2023-06-01T00:00:00.000' AS DateTime), CAST(N'2024-04-11T00:00:00.000' AS DateTime), CAST(N'2024-01-17T00:00:00.000' AS DateTime), 46, 6, 49, 53)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (27, 3, CAST(N'2023-07-15T00:00:00.000' AS DateTime), CAST(N'2023-08-01T00:00:00.000' AS DateTime), CAST(N'2024-02-18T00:00:00.000' AS DateTime), CAST(N'2024-03-27T00:00:00.000' AS DateTime), 16, 19, 47, 86)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (28, 5, CAST(N'2024-03-02T00:00:00.000' AS DateTime), CAST(N'2024-05-06T00:00:00.000' AS DateTime), CAST(N'2023-11-01T00:00:00.000' AS DateTime), CAST(N'2024-03-02T00:00:00.000' AS DateTime), 15, 32, 33, 371)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (29, 9, CAST(N'2023-09-09T00:00:00.000' AS DateTime), CAST(N'2024-02-24T00:00:00.000' AS DateTime), CAST(N'2024-05-21T00:00:00.000' AS DateTime), CAST(N'2024-01-20T00:00:00.000' AS DateTime), 39, 17, 16, 179)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (30, 3, CAST(N'2023-12-28T00:00:00.000' AS DateTime), CAST(N'2023-10-02T00:00:00.000' AS DateTime), CAST(N'2023-07-15T00:00:00.000' AS DateTime), CAST(N'2023-07-30T00:00:00.000' AS DateTime), 49, 16, 41, 358)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (31, 7, CAST(N'2023-11-13T00:00:00.000' AS DateTime), CAST(N'2024-01-01T00:00:00.000' AS DateTime), CAST(N'2023-09-02T00:00:00.000' AS DateTime), CAST(N'2023-11-21T00:00:00.000' AS DateTime), 23, 47, 42, 331)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (32, 1, CAST(N'2024-03-02T00:00:00.000' AS DateTime), CAST(N'2024-05-13T00:00:00.000' AS DateTime), CAST(N'2024-05-13T00:00:00.000' AS DateTime), CAST(N'2024-05-20T00:00:00.000' AS DateTime), 36, 43, 39, 39)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (33, 5, CAST(N'2024-05-27T00:00:00.000' AS DateTime), CAST(N'2024-03-27T00:00:00.000' AS DateTime), CAST(N'2024-03-29T00:00:00.000' AS DateTime), CAST(N'2023-12-18T00:00:00.000' AS DateTime), 4, 27, 29, 53)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (34, 10, CAST(N'2024-03-18T00:00:00.000' AS DateTime), CAST(N'2023-09-24T00:00:00.000' AS DateTime), CAST(N'2023-06-24T00:00:00.000' AS DateTime), CAST(N'2024-04-07T00:00:00.000' AS DateTime), 23, 9, 36, 243)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (35, 2, CAST(N'2023-06-01T00:00:00.000' AS DateTime), CAST(N'2024-03-04T00:00:00.000' AS DateTime), CAST(N'2023-07-23T00:00:00.000' AS DateTime), CAST(N'2023-08-08T00:00:00.000' AS DateTime), 49, 10, 25, 221)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (36, 10, CAST(N'2023-07-31T00:00:00.000' AS DateTime), CAST(N'2023-12-08T00:00:00.000' AS DateTime), CAST(N'2024-05-22T00:00:00.000' AS DateTime), CAST(N'2023-12-25T00:00:00.000' AS DateTime), 43, 43, 12, 300)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (37, 10, CAST(N'2024-02-20T00:00:00.000' AS DateTime), CAST(N'2023-09-26T00:00:00.000' AS DateTime), CAST(N'2023-12-29T00:00:00.000' AS DateTime), CAST(N'2024-04-22T00:00:00.000' AS DateTime), 15, 36, 48, 73)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (38, 10, CAST(N'2023-10-20T00:00:00.000' AS DateTime), CAST(N'2024-01-24T00:00:00.000' AS DateTime), CAST(N'2023-11-29T00:00:00.000' AS DateTime), CAST(N'2024-01-05T00:00:00.000' AS DateTime), 28, 28, 35, 118)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (39, 9, CAST(N'2023-12-29T00:00:00.000' AS DateTime), CAST(N'2023-08-30T00:00:00.000' AS DateTime), CAST(N'2023-06-29T00:00:00.000' AS DateTime), CAST(N'2023-08-12T00:00:00.000' AS DateTime), 18, 19, 49, 218)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (40, 8, CAST(N'2024-03-04T00:00:00.000' AS DateTime), CAST(N'2023-12-25T00:00:00.000' AS DateTime), CAST(N'2024-03-04T00:00:00.000' AS DateTime), CAST(N'2024-01-31T00:00:00.000' AS DateTime), 31, 9, 46, 50)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (41, 5, CAST(N'2023-12-01T00:00:00.000' AS DateTime), CAST(N'2024-04-15T00:00:00.000' AS DateTime), CAST(N'2024-04-13T00:00:00.000' AS DateTime), CAST(N'2023-09-26T00:00:00.000' AS DateTime), 34, 43, 46, 383)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (42, 10, CAST(N'2024-05-07T00:00:00.000' AS DateTime), CAST(N'2024-05-25T00:00:00.000' AS DateTime), CAST(N'2023-06-19T00:00:00.000' AS DateTime), CAST(N'2024-05-29T00:00:00.000' AS DateTime), 22, 14, 41, 363)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (43, 6, CAST(N'2023-10-14T00:00:00.000' AS DateTime), CAST(N'2023-10-29T00:00:00.000' AS DateTime), CAST(N'2023-07-26T00:00:00.000' AS DateTime), CAST(N'2024-04-15T00:00:00.000' AS DateTime), 25, 28, 50, 252)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (44, 7, CAST(N'2023-12-03T00:00:00.000' AS DateTime), CAST(N'2023-09-04T00:00:00.000' AS DateTime), CAST(N'2023-12-23T00:00:00.000' AS DateTime), CAST(N'2024-04-08T00:00:00.000' AS DateTime), 49, 22, 31, 217)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (45, 3, CAST(N'2024-04-02T00:00:00.000' AS DateTime), CAST(N'2023-10-29T00:00:00.000' AS DateTime), CAST(N'2023-12-14T00:00:00.000' AS DateTime), CAST(N'2024-05-20T00:00:00.000' AS DateTime), 27, 10, 12, 284)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (46, 10, CAST(N'2024-01-22T00:00:00.000' AS DateTime), CAST(N'2023-11-17T00:00:00.000' AS DateTime), CAST(N'2024-02-02T00:00:00.000' AS DateTime), CAST(N'2024-02-12T00:00:00.000' AS DateTime), 17, 38, 25, 239)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (47, 2, CAST(N'2024-04-24T00:00:00.000' AS DateTime), CAST(N'2023-10-14T00:00:00.000' AS DateTime), CAST(N'2023-12-28T00:00:00.000' AS DateTime), CAST(N'2024-04-19T00:00:00.000' AS DateTime), 44, 5, 1, 268)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (48, 9, CAST(N'2023-10-23T00:00:00.000' AS DateTime), CAST(N'2023-11-26T00:00:00.000' AS DateTime), CAST(N'2024-04-22T00:00:00.000' AS DateTime), CAST(N'2023-06-22T00:00:00.000' AS DateTime), 13, 13, 41, 391)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (49, 4, CAST(N'2024-04-19T00:00:00.000' AS DateTime), CAST(N'2023-09-23T00:00:00.000' AS DateTime), CAST(N'2024-02-04T00:00:00.000' AS DateTime), CAST(N'2023-10-29T00:00:00.000' AS DateTime), 28, 31, 43, 56)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (50, 2, CAST(N'2023-06-16T00:00:00.000' AS DateTime), CAST(N'2023-11-25T00:00:00.000' AS DateTime), CAST(N'2023-08-31T00:00:00.000' AS DateTime), CAST(N'2023-12-05T00:00:00.000' AS DateTime), 8, 30, 12, 174)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (51, 6, CAST(N'2023-10-01T00:00:00.000' AS DateTime), CAST(N'2023-08-14T00:00:00.000' AS DateTime), CAST(N'2023-11-25T00:00:00.000' AS DateTime), CAST(N'2023-09-25T00:00:00.000' AS DateTime), 1, 15, 47, 17)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (52, 1, CAST(N'2024-05-24T00:00:00.000' AS DateTime), CAST(N'2024-05-22T00:00:00.000' AS DateTime), CAST(N'2024-05-30T00:00:00.000' AS DateTime), CAST(N'2024-03-04T00:00:00.000' AS DateTime), 43, 43, 39, 61)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (53, 9, CAST(N'2024-03-06T00:00:00.000' AS DateTime), CAST(N'2023-07-15T00:00:00.000' AS DateTime), CAST(N'2023-09-06T00:00:00.000' AS DateTime), CAST(N'2023-06-01T00:00:00.000' AS DateTime), 39, 35, 4, 153)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (54, 8, CAST(N'2024-01-17T00:00:00.000' AS DateTime), CAST(N'2023-11-18T00:00:00.000' AS DateTime), CAST(N'2023-08-20T00:00:00.000' AS DateTime), CAST(N'2023-10-29T00:00:00.000' AS DateTime), 37, 29, 41, 283)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (55, 4, CAST(N'2024-01-10T00:00:00.000' AS DateTime), CAST(N'2024-05-10T00:00:00.000' AS DateTime), CAST(N'2023-08-10T00:00:00.000' AS DateTime), CAST(N'2023-10-29T00:00:00.000' AS DateTime), 45, 8, 12, 98)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (56, 4, CAST(N'2023-10-12T00:00:00.000' AS DateTime), CAST(N'2023-11-20T00:00:00.000' AS DateTime), CAST(N'2024-05-07T00:00:00.000' AS DateTime), CAST(N'2024-04-15T00:00:00.000' AS DateTime), 29, 2, 35, 188)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (57, 5, CAST(N'2023-06-17T00:00:00.000' AS DateTime), CAST(N'2023-06-14T00:00:00.000' AS DateTime), CAST(N'2024-01-11T00:00:00.000' AS DateTime), CAST(N'2023-08-22T00:00:00.000' AS DateTime), 30, 36, 9, 136)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (58, 7, CAST(N'2023-11-09T00:00:00.000' AS DateTime), CAST(N'2023-08-24T00:00:00.000' AS DateTime), CAST(N'2024-02-26T00:00:00.000' AS DateTime), CAST(N'2024-05-06T00:00:00.000' AS DateTime), 3, 18, 49, 71)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (59, 7, CAST(N'2023-12-02T00:00:00.000' AS DateTime), CAST(N'2023-08-07T00:00:00.000' AS DateTime), CAST(N'2023-07-08T00:00:00.000' AS DateTime), CAST(N'2024-04-01T00:00:00.000' AS DateTime), 19, 1, 11, 352)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (60, 8, CAST(N'2024-01-15T00:00:00.000' AS DateTime), CAST(N'2023-10-03T00:00:00.000' AS DateTime), CAST(N'2023-08-15T00:00:00.000' AS DateTime), CAST(N'2023-06-17T00:00:00.000' AS DateTime), 2, 36, 14, 126)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (61, 9, CAST(N'2023-07-28T00:00:00.000' AS DateTime), CAST(N'2024-04-01T00:00:00.000' AS DateTime), CAST(N'2024-02-29T00:00:00.000' AS DateTime), CAST(N'2023-11-04T00:00:00.000' AS DateTime), 21, 46, 39, 40)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (62, 4, CAST(N'2023-09-24T00:00:00.000' AS DateTime), CAST(N'2023-07-08T00:00:00.000' AS DateTime), CAST(N'2023-07-20T00:00:00.000' AS DateTime), CAST(N'2024-02-04T00:00:00.000' AS DateTime), 8, 41, 45, 316)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (63, 6, CAST(N'2024-01-03T00:00:00.000' AS DateTime), CAST(N'2023-12-12T00:00:00.000' AS DateTime), CAST(N'2024-01-10T00:00:00.000' AS DateTime), CAST(N'2024-02-24T00:00:00.000' AS DateTime), 23, 14, 6, 391)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (64, 10, CAST(N'2023-11-15T00:00:00.000' AS DateTime), CAST(N'2023-09-28T00:00:00.000' AS DateTime), CAST(N'2023-10-22T00:00:00.000' AS DateTime), CAST(N'2023-07-31T00:00:00.000' AS DateTime), 33, 46, 3, 7)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (65, 1, CAST(N'2024-04-10T00:00:00.000' AS DateTime), CAST(N'2023-10-09T00:00:00.000' AS DateTime), CAST(N'2023-08-01T00:00:00.000' AS DateTime), CAST(N'2023-08-13T00:00:00.000' AS DateTime), 6, 49, 17, 398)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (66, 1, CAST(N'2024-01-13T00:00:00.000' AS DateTime), CAST(N'2023-06-04T00:00:00.000' AS DateTime), CAST(N'2023-10-30T00:00:00.000' AS DateTime), CAST(N'2024-01-06T00:00:00.000' AS DateTime), 25, 40, 6, 315)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (67, 1, CAST(N'2023-10-06T00:00:00.000' AS DateTime), CAST(N'2024-01-29T00:00:00.000' AS DateTime), CAST(N'2023-09-09T00:00:00.000' AS DateTime), CAST(N'2023-12-27T00:00:00.000' AS DateTime), 13, 13, 35, 17)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (68, 6, CAST(N'2023-07-01T00:00:00.000' AS DateTime), CAST(N'2023-08-17T00:00:00.000' AS DateTime), CAST(N'2024-04-03T00:00:00.000' AS DateTime), CAST(N'2024-02-05T00:00:00.000' AS DateTime), 44, 33, 20, 224)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (69, 6, CAST(N'2024-05-30T00:00:00.000' AS DateTime), CAST(N'2023-07-12T00:00:00.000' AS DateTime), CAST(N'2024-05-07T00:00:00.000' AS DateTime), CAST(N'2024-05-26T00:00:00.000' AS DateTime), 21, 2, 37, 29)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (70, 3, CAST(N'2023-09-19T00:00:00.000' AS DateTime), CAST(N'2023-10-27T00:00:00.000' AS DateTime), CAST(N'2024-01-26T00:00:00.000' AS DateTime), CAST(N'2024-01-04T00:00:00.000' AS DateTime), 35, 17, 47, 129)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (71, 3, CAST(N'2023-09-06T00:00:00.000' AS DateTime), CAST(N'2023-08-14T00:00:00.000' AS DateTime), CAST(N'2023-09-16T00:00:00.000' AS DateTime), CAST(N'2023-10-10T00:00:00.000' AS DateTime), 1, 44, 5, 57)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (72, 4, CAST(N'2023-06-22T00:00:00.000' AS DateTime), CAST(N'2023-12-14T00:00:00.000' AS DateTime), CAST(N'2023-11-10T00:00:00.000' AS DateTime), CAST(N'2024-01-17T00:00:00.000' AS DateTime), 49, 22, 24, 285)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (73, 9, CAST(N'2023-10-25T00:00:00.000' AS DateTime), CAST(N'2024-05-31T00:00:00.000' AS DateTime), CAST(N'2024-05-28T00:00:00.000' AS DateTime), CAST(N'2024-01-22T00:00:00.000' AS DateTime), 36, 37, 36, 106)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (74, 3, CAST(N'2024-04-24T00:00:00.000' AS DateTime), CAST(N'2024-02-19T00:00:00.000' AS DateTime), CAST(N'2023-06-25T00:00:00.000' AS DateTime), CAST(N'2023-12-08T00:00:00.000' AS DateTime), 29, 44, 49, 193)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (75, 10, CAST(N'2024-05-18T00:00:00.000' AS DateTime), CAST(N'2024-02-02T00:00:00.000' AS DateTime), CAST(N'2023-12-03T00:00:00.000' AS DateTime), CAST(N'2023-06-14T00:00:00.000' AS DateTime), 33, 22, 42, 318)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (76, 6, CAST(N'2023-09-13T00:00:00.000' AS DateTime), CAST(N'2023-06-25T00:00:00.000' AS DateTime), CAST(N'2023-10-26T00:00:00.000' AS DateTime), CAST(N'2023-06-03T00:00:00.000' AS DateTime), 27, 23, 9, 289)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (77, 3, CAST(N'2023-07-10T00:00:00.000' AS DateTime), CAST(N'2024-01-06T00:00:00.000' AS DateTime), CAST(N'2023-11-16T00:00:00.000' AS DateTime), CAST(N'2023-11-03T00:00:00.000' AS DateTime), 34, 49, 37, 398)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (78, 8, CAST(N'2023-06-19T00:00:00.000' AS DateTime), CAST(N'2023-12-06T00:00:00.000' AS DateTime), CAST(N'2023-10-26T00:00:00.000' AS DateTime), CAST(N'2023-12-17T00:00:00.000' AS DateTime), 28, 12, 12, 281)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (79, 3, CAST(N'2024-01-30T00:00:00.000' AS DateTime), CAST(N'2023-07-10T00:00:00.000' AS DateTime), CAST(N'2024-04-06T00:00:00.000' AS DateTime), CAST(N'2024-04-21T00:00:00.000' AS DateTime), 15, 1, 38, 197)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (80, 10, CAST(N'2024-04-24T00:00:00.000' AS DateTime), CAST(N'2024-04-17T00:00:00.000' AS DateTime), CAST(N'2023-12-24T00:00:00.000' AS DateTime), CAST(N'2023-10-23T00:00:00.000' AS DateTime), 28, 39, 17, 206)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (81, 9, CAST(N'2024-03-26T00:00:00.000' AS DateTime), CAST(N'2023-11-26T00:00:00.000' AS DateTime), CAST(N'2024-01-02T00:00:00.000' AS DateTime), CAST(N'2023-07-17T00:00:00.000' AS DateTime), 40, 50, 23, 83)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (82, 6, CAST(N'2023-08-27T00:00:00.000' AS DateTime), CAST(N'2023-07-30T00:00:00.000' AS DateTime), CAST(N'2023-09-29T00:00:00.000' AS DateTime), CAST(N'2024-03-25T00:00:00.000' AS DateTime), 3, 35, 22, 45)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (83, 3, CAST(N'2023-12-15T00:00:00.000' AS DateTime), CAST(N'2023-11-05T00:00:00.000' AS DateTime), CAST(N'2023-10-07T00:00:00.000' AS DateTime), CAST(N'2024-01-29T00:00:00.000' AS DateTime), 36, 2, 17, 157)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (84, 3, CAST(N'2024-03-02T00:00:00.000' AS DateTime), CAST(N'2023-12-29T00:00:00.000' AS DateTime), CAST(N'2023-08-14T00:00:00.000' AS DateTime), CAST(N'2024-05-05T00:00:00.000' AS DateTime), 7, 49, 3, 196)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (85, 8, CAST(N'2024-01-27T00:00:00.000' AS DateTime), CAST(N'2023-07-03T00:00:00.000' AS DateTime), CAST(N'2024-03-18T00:00:00.000' AS DateTime), CAST(N'2024-02-06T00:00:00.000' AS DateTime), 16, 23, 17, 290)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (86, 1, CAST(N'2024-02-22T00:00:00.000' AS DateTime), CAST(N'2023-07-09T00:00:00.000' AS DateTime), CAST(N'2024-04-09T00:00:00.000' AS DateTime), CAST(N'2024-03-02T00:00:00.000' AS DateTime), 33, 47, 18, 381)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (87, 1, CAST(N'2023-09-25T00:00:00.000' AS DateTime), CAST(N'2024-04-30T00:00:00.000' AS DateTime), CAST(N'2023-12-19T00:00:00.000' AS DateTime), CAST(N'2024-05-12T00:00:00.000' AS DateTime), 13, 6, 19, 212)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (88, 8, CAST(N'2023-12-11T00:00:00.000' AS DateTime), CAST(N'2023-09-09T00:00:00.000' AS DateTime), CAST(N'2024-01-15T00:00:00.000' AS DateTime), CAST(N'2024-01-18T00:00:00.000' AS DateTime), 28, 3, 29, 114)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (89, 10, CAST(N'2024-02-21T00:00:00.000' AS DateTime), CAST(N'2024-01-07T00:00:00.000' AS DateTime), CAST(N'2023-07-19T00:00:00.000' AS DateTime), CAST(N'2023-10-21T00:00:00.000' AS DateTime), 49, 3, 25, 233)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (90, 8, CAST(N'2024-03-04T00:00:00.000' AS DateTime), CAST(N'2023-08-29T00:00:00.000' AS DateTime), CAST(N'2024-02-19T00:00:00.000' AS DateTime), CAST(N'2023-12-23T00:00:00.000' AS DateTime), 6, 47, 38, 10)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (91, 5, CAST(N'2023-07-10T00:00:00.000' AS DateTime), CAST(N'2023-07-07T00:00:00.000' AS DateTime), CAST(N'2024-03-04T00:00:00.000' AS DateTime), CAST(N'2024-02-23T00:00:00.000' AS DateTime), 36, 9, 3, 5)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (92, 8, CAST(N'2023-12-10T00:00:00.000' AS DateTime), CAST(N'2023-11-03T00:00:00.000' AS DateTime), CAST(N'2023-07-25T00:00:00.000' AS DateTime), CAST(N'2024-04-19T00:00:00.000' AS DateTime), 25, 19, 13, 46)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (93, 9, CAST(N'2024-02-19T00:00:00.000' AS DateTime), CAST(N'2023-07-22T00:00:00.000' AS DateTime), CAST(N'2024-05-25T00:00:00.000' AS DateTime), CAST(N'2023-12-04T00:00:00.000' AS DateTime), 10, 47, 38, 374)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (94, 2, CAST(N'2024-02-11T00:00:00.000' AS DateTime), CAST(N'2024-02-28T00:00:00.000' AS DateTime), CAST(N'2023-10-12T00:00:00.000' AS DateTime), CAST(N'2024-05-03T00:00:00.000' AS DateTime), 26, 9, 32, 45)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (95, 10, CAST(N'2023-11-18T00:00:00.000' AS DateTime), CAST(N'2024-04-14T00:00:00.000' AS DateTime), CAST(N'2024-01-31T00:00:00.000' AS DateTime), CAST(N'2023-12-11T00:00:00.000' AS DateTime), 42, 29, 13, 378)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (96, 9, CAST(N'2023-12-26T00:00:00.000' AS DateTime), CAST(N'2024-05-03T00:00:00.000' AS DateTime), CAST(N'2023-08-09T00:00:00.000' AS DateTime), CAST(N'2024-03-01T00:00:00.000' AS DateTime), 36, 45, 13, 295)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (97, 1, CAST(N'2023-06-04T00:00:00.000' AS DateTime), CAST(N'2023-12-07T00:00:00.000' AS DateTime), CAST(N'2024-03-18T00:00:00.000' AS DateTime), CAST(N'2023-07-18T00:00:00.000' AS DateTime), 22, 6, 36, 245)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (98, 7, CAST(N'2024-03-08T00:00:00.000' AS DateTime), CAST(N'2023-11-07T00:00:00.000' AS DateTime), CAST(N'2023-10-01T00:00:00.000' AS DateTime), CAST(N'2024-03-31T00:00:00.000' AS DateTime), 38, 33, 40, 5)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (99, 8, CAST(N'2024-03-02T00:00:00.000' AS DateTime), CAST(N'2023-12-22T00:00:00.000' AS DateTime), CAST(N'2023-08-06T00:00:00.000' AS DateTime), CAST(N'2023-09-11T00:00:00.000' AS DateTime), 26, 40, 20, 365)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (100, 6, CAST(N'2024-01-22T00:00:00.000' AS DateTime), CAST(N'2023-08-15T00:00:00.000' AS DateTime), CAST(N'2023-09-11T00:00:00.000' AS DateTime), CAST(N'2023-09-08T00:00:00.000' AS DateTime), 6, 6, 47, 47)
GO

-- %%
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (101, 2, CAST(N'2024-05-31T00:00:00.000' AS DateTime), CAST(N'2023-07-18T00:00:00.000' AS DateTime), CAST(N'2023-11-16T00:00:00.000' AS DateTime), CAST(N'2023-10-05T00:00:00.000' AS DateTime), 44, 14, 7, 270)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (102, 10, CAST(N'2024-03-25T00:00:00.000' AS DateTime), CAST(N'2024-01-04T00:00:00.000' AS DateTime), CAST(N'2023-11-08T00:00:00.000' AS DateTime), CAST(N'2024-01-29T00:00:00.000' AS DateTime), 19, 7, 24, 385)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (103, 3, CAST(N'2024-04-01T00:00:00.000' AS DateTime), CAST(N'2023-08-30T00:00:00.000' AS DateTime), CAST(N'2024-04-07T00:00:00.000' AS DateTime), CAST(N'2024-05-27T00:00:00.000' AS DateTime), 17, 45, 48, 60)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (104, 9, CAST(N'2023-10-23T00:00:00.000' AS DateTime), CAST(N'2023-09-05T00:00:00.000' AS DateTime), CAST(N'2023-06-23T00:00:00.000' AS DateTime), CAST(N'2023-11-01T00:00:00.000' AS DateTime), 45, 47, 8, 178)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (105, 6, CAST(N'2024-01-21T00:00:00.000' AS DateTime), CAST(N'2024-03-16T00:00:00.000' AS DateTime), CAST(N'2023-06-06T00:00:00.000' AS DateTime), CAST(N'2023-10-22T00:00:00.000' AS DateTime), 8, 23, 30, 358)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (106, 10, CAST(N'2023-10-28T00:00:00.000' AS DateTime), CAST(N'2024-01-30T00:00:00.000' AS DateTime), CAST(N'2024-01-15T00:00:00.000' AS DateTime), CAST(N'2023-07-26T00:00:00.000' AS DateTime), 20, 10, 45, 230)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (107, 10, CAST(N'2024-05-29T00:00:00.000' AS DateTime), CAST(N'2024-05-15T00:00:00.000' AS DateTime), CAST(N'2023-07-12T00:00:00.000' AS DateTime), CAST(N'2023-10-02T00:00:00.000' AS DateTime), 49, 43, 46, 163)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (108, 3, CAST(N'2024-01-14T00:00:00.000' AS DateTime), CAST(N'2023-07-10T00:00:00.000' AS DateTime), CAST(N'2023-07-05T00:00:00.000' AS DateTime), CAST(N'2023-06-05T00:00:00.000' AS DateTime), 1, 19, 40, 176)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (109, 10, CAST(N'2024-05-26T00:00:00.000' AS DateTime), CAST(N'2024-04-10T00:00:00.000' AS DateTime), CAST(N'2023-08-24T00:00:00.000' AS DateTime), CAST(N'2024-03-15T00:00:00.000' AS DateTime), 19, 38, 25, 258)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (110, 3, CAST(N'2024-04-25T00:00:00.000' AS DateTime), CAST(N'2024-05-13T00:00:00.000' AS DateTime), CAST(N'2024-01-28T00:00:00.000' AS DateTime), CAST(N'2024-02-08T00:00:00.000' AS DateTime), 49, 39, 15, 42)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (111, 4, CAST(N'2024-04-13T00:00:00.000' AS DateTime), CAST(N'2023-06-07T00:00:00.000' AS DateTime), CAST(N'2023-11-26T00:00:00.000' AS DateTime), CAST(N'2024-03-25T00:00:00.000' AS DateTime), 34, 22, 2, 257)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (112, 3, CAST(N'2024-04-09T00:00:00.000' AS DateTime), CAST(N'2023-10-18T00:00:00.000' AS DateTime), CAST(N'2023-08-15T00:00:00.000' AS DateTime), CAST(N'2023-09-11T00:00:00.000' AS DateTime), 7, 25, 13, 306)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (113, 2, CAST(N'2023-09-01T00:00:00.000' AS DateTime), CAST(N'2023-06-17T00:00:00.000' AS DateTime), CAST(N'2023-11-26T00:00:00.000' AS DateTime), CAST(N'2023-06-26T00:00:00.000' AS DateTime), 24, 8, 21, 326)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (114, 7, CAST(N'2024-01-24T00:00:00.000' AS DateTime), CAST(N'2024-03-05T00:00:00.000' AS DateTime), CAST(N'2024-02-08T00:00:00.000' AS DateTime), CAST(N'2024-05-29T00:00:00.000' AS DateTime), 22, 25, 50, 222)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (115, 2, CAST(N'2024-04-05T00:00:00.000' AS DateTime), CAST(N'2023-09-05T00:00:00.000' AS DateTime), CAST(N'2023-09-15T00:00:00.000' AS DateTime), CAST(N'2023-06-24T00:00:00.000' AS DateTime), 2, 39, 37, 163)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (116, 8, CAST(N'2024-03-03T00:00:00.000' AS DateTime), CAST(N'2023-09-09T00:00:00.000' AS DateTime), CAST(N'2023-09-16T00:00:00.000' AS DateTime), CAST(N'2024-04-17T00:00:00.000' AS DateTime), 32, 49, 2, 237)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (117, 10, CAST(N'2023-07-26T00:00:00.000' AS DateTime), CAST(N'2023-09-12T00:00:00.000' AS DateTime), CAST(N'2023-10-18T00:00:00.000' AS DateTime), CAST(N'2024-03-15T00:00:00.000' AS DateTime), 29, 16, 10, 312)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (118, 3, CAST(N'2024-01-02T00:00:00.000' AS DateTime), CAST(N'2023-10-16T00:00:00.000' AS DateTime), CAST(N'2024-01-07T00:00:00.000' AS DateTime), CAST(N'2023-09-29T00:00:00.000' AS DateTime), 21, 29, 3, 248)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (119, 9, CAST(N'2023-09-13T00:00:00.000' AS DateTime), CAST(N'2023-09-15T00:00:00.000' AS DateTime), CAST(N'2023-12-03T00:00:00.000' AS DateTime), CAST(N'2023-10-10T00:00:00.000' AS DateTime), 46, 35, 23, 61)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (120, 8, CAST(N'2024-03-13T00:00:00.000' AS DateTime), CAST(N'2023-07-12T00:00:00.000' AS DateTime), CAST(N'2024-05-17T00:00:00.000' AS DateTime), CAST(N'2023-11-28T00:00:00.000' AS DateTime), 13, 46, 35, 317)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (121, 6, CAST(N'2024-02-05T00:00:00.000' AS DateTime), CAST(N'2023-09-18T00:00:00.000' AS DateTime), CAST(N'2024-04-22T00:00:00.000' AS DateTime), CAST(N'2023-06-21T00:00:00.000' AS DateTime), 6, 36, 15, 331)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (122, 5, CAST(N'2023-06-15T00:00:00.000' AS DateTime), CAST(N'2024-01-20T00:00:00.000' AS DateTime), CAST(N'2023-09-17T00:00:00.000' AS DateTime), CAST(N'2024-03-23T00:00:00.000' AS DateTime), 13, 4, 44, 331)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (123, 10, CAST(N'2023-09-10T00:00:00.000' AS DateTime), CAST(N'2023-07-12T00:00:00.000' AS DateTime), CAST(N'2023-06-28T00:00:00.000' AS DateTime), CAST(N'2024-01-16T00:00:00.000' AS DateTime), 5, 21, 45, 41)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (124, 10, CAST(N'2023-11-18T00:00:00.000' AS DateTime), CAST(N'2023-08-26T00:00:00.000' AS DateTime), CAST(N'2023-09-29T00:00:00.000' AS DateTime), CAST(N'2023-07-21T00:00:00.000' AS DateTime), 29, 45, 7, 82)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (125, 2, CAST(N'2024-02-20T00:00:00.000' AS DateTime), CAST(N'2023-06-05T00:00:00.000' AS DateTime), CAST(N'2024-03-26T00:00:00.000' AS DateTime), CAST(N'2024-04-16T00:00:00.000' AS DateTime), 13, 20, 41, 303)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (126, 8, CAST(N'2023-10-10T00:00:00.000' AS DateTime), CAST(N'2023-12-25T00:00:00.000' AS DateTime), CAST(N'2023-08-24T00:00:00.000' AS DateTime), CAST(N'2023-12-10T00:00:00.000' AS DateTime), 33, 7, 36, 309)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (127, 4, CAST(N'2024-03-22T00:00:00.000' AS DateTime), CAST(N'2024-05-06T00:00:00.000' AS DateTime), CAST(N'2024-03-04T00:00:00.000' AS DateTime), CAST(N'2023-09-21T00:00:00.000' AS DateTime), 31, 9, 25, 235)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (128, 5, CAST(N'2023-11-20T00:00:00.000' AS DateTime), CAST(N'2023-11-22T00:00:00.000' AS DateTime), CAST(N'2024-05-01T00:00:00.000' AS DateTime), CAST(N'2023-10-05T00:00:00.000' AS DateTime), 29, 47, 41, 357)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (129, 9, CAST(N'2024-03-18T00:00:00.000' AS DateTime), CAST(N'2023-10-13T00:00:00.000' AS DateTime), CAST(N'2023-07-14T00:00:00.000' AS DateTime), CAST(N'2024-02-21T00:00:00.000' AS DateTime), 15, 17, 39, 122)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (130, 7, CAST(N'2023-09-27T00:00:00.000' AS DateTime), CAST(N'2023-10-06T00:00:00.000' AS DateTime), CAST(N'2024-03-24T00:00:00.000' AS DateTime), CAST(N'2023-10-08T00:00:00.000' AS DateTime), 6, 29, 11, 112)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (131, 8, CAST(N'2023-11-05T00:00:00.000' AS DateTime), CAST(N'2023-10-12T00:00:00.000' AS DateTime), CAST(N'2023-10-18T00:00:00.000' AS DateTime), CAST(N'2023-08-19T00:00:00.000' AS DateTime), 25, 34, 11, 235)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (132, 8, CAST(N'2023-10-22T00:00:00.000' AS DateTime), CAST(N'2023-09-29T00:00:00.000' AS DateTime), CAST(N'2024-01-16T00:00:00.000' AS DateTime), CAST(N'2023-08-03T00:00:00.000' AS DateTime), 22, 34, 35, 69)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (133, 9, CAST(N'2023-10-16T00:00:00.000' AS DateTime), CAST(N'2024-03-22T00:00:00.000' AS DateTime), CAST(N'2023-06-22T00:00:00.000' AS DateTime), CAST(N'2023-11-21T00:00:00.000' AS DateTime), 42, 37, 6, 342)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (134, 9, CAST(N'2024-02-04T00:00:00.000' AS DateTime), CAST(N'2023-09-10T00:00:00.000' AS DateTime), CAST(N'2023-08-24T00:00:00.000' AS DateTime), CAST(N'2023-10-25T00:00:00.000' AS DateTime), 17, 41, 11, 146)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (135, 6, CAST(N'2024-05-08T00:00:00.000' AS DateTime), CAST(N'2023-10-14T00:00:00.000' AS DateTime), CAST(N'2024-01-17T00:00:00.000' AS DateTime), CAST(N'2023-09-05T00:00:00.000' AS DateTime), 16, 27, 13, 120)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (136, 2, CAST(N'2023-06-26T00:00:00.000' AS DateTime), CAST(N'2023-11-07T00:00:00.000' AS DateTime), CAST(N'2023-12-23T00:00:00.000' AS DateTime), CAST(N'2023-07-21T00:00:00.000' AS DateTime), 23, 45, 19, 29)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (137, 8, CAST(N'2024-03-12T00:00:00.000' AS DateTime), CAST(N'2023-12-05T00:00:00.000' AS DateTime), CAST(N'2023-08-30T00:00:00.000' AS DateTime), CAST(N'2024-02-28T00:00:00.000' AS DateTime), 49, 4, 25, 309)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (138, 10, CAST(N'2023-06-30T00:00:00.000' AS DateTime), CAST(N'2023-11-30T00:00:00.000' AS DateTime), CAST(N'2024-02-29T00:00:00.000' AS DateTime), CAST(N'2023-08-17T00:00:00.000' AS DateTime), 11, 3, 18, 138)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (139, 8, CAST(N'2024-02-10T00:00:00.000' AS DateTime), CAST(N'2023-06-24T00:00:00.000' AS DateTime), CAST(N'2023-08-27T00:00:00.000' AS DateTime), CAST(N'2024-02-23T00:00:00.000' AS DateTime), 23, 38, 16, 182)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (140, 6, CAST(N'2023-06-30T00:00:00.000' AS DateTime), CAST(N'2023-09-02T00:00:00.000' AS DateTime), CAST(N'2023-11-05T00:00:00.000' AS DateTime), CAST(N'2024-03-30T00:00:00.000' AS DateTime), 46, 36, 34, 363)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (141, 10, CAST(N'2023-07-03T00:00:00.000' AS DateTime), CAST(N'2023-07-29T00:00:00.000' AS DateTime), CAST(N'2023-09-27T00:00:00.000' AS DateTime), CAST(N'2023-06-05T00:00:00.000' AS DateTime), 30, 9, 34, 328)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (142, 2, CAST(N'2024-02-09T00:00:00.000' AS DateTime), CAST(N'2023-09-15T00:00:00.000' AS DateTime), CAST(N'2023-08-16T00:00:00.000' AS DateTime), CAST(N'2023-12-16T00:00:00.000' AS DateTime), 47, 43, 27, 234)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (143, 7, CAST(N'2024-05-17T00:00:00.000' AS DateTime), CAST(N'2024-03-15T00:00:00.000' AS DateTime), CAST(N'2023-07-17T00:00:00.000' AS DateTime), CAST(N'2023-09-18T00:00:00.000' AS DateTime), 29, 40, 33, 342)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (144, 1, CAST(N'2023-07-27T00:00:00.000' AS DateTime), CAST(N'2023-06-25T00:00:00.000' AS DateTime), CAST(N'2023-10-01T00:00:00.000' AS DateTime), CAST(N'2024-01-05T00:00:00.000' AS DateTime), 46, 46, 42, 47)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (145, 7, CAST(N'2023-08-03T00:00:00.000' AS DateTime), CAST(N'2023-09-21T00:00:00.000' AS DateTime), CAST(N'2023-06-22T00:00:00.000' AS DateTime), CAST(N'2024-04-10T00:00:00.000' AS DateTime), 20, 46, 1, 185)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (146, 8, CAST(N'2023-10-17T00:00:00.000' AS DateTime), CAST(N'2023-10-03T00:00:00.000' AS DateTime), CAST(N'2023-10-10T00:00:00.000' AS DateTime), CAST(N'2023-10-30T00:00:00.000' AS DateTime), 7, 37, 33, 73)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (147, 1, CAST(N'2023-07-15T00:00:00.000' AS DateTime), CAST(N'2023-09-10T00:00:00.000' AS DateTime), CAST(N'2023-08-29T00:00:00.000' AS DateTime), CAST(N'2023-12-08T00:00:00.000' AS DateTime), 4, 40, 32, 80)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (148, 7, CAST(N'2023-06-15T00:00:00.000' AS DateTime), CAST(N'2024-05-26T00:00:00.000' AS DateTime), CAST(N'2024-03-06T00:00:00.000' AS DateTime), CAST(N'2024-04-07T00:00:00.000' AS DateTime), 5, 48, 41, 337)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (149, 2, CAST(N'2024-04-18T00:00:00.000' AS DateTime), CAST(N'2023-10-22T00:00:00.000' AS DateTime), CAST(N'2024-04-08T00:00:00.000' AS DateTime), CAST(N'2023-11-25T00:00:00.000' AS DateTime), 5, 42, 18, 332)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (150, 5, CAST(N'2023-09-22T00:00:00.000' AS DateTime), CAST(N'2024-05-29T00:00:00.000' AS DateTime), CAST(N'2024-01-22T00:00:00.000' AS DateTime), CAST(N'2024-05-02T00:00:00.000' AS DateTime), 9, 35, 33, 335)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (151, 5, CAST(N'2024-02-22T00:00:00.000' AS DateTime), CAST(N'2023-07-14T00:00:00.000' AS DateTime), CAST(N'2024-03-11T00:00:00.000' AS DateTime), CAST(N'2023-10-05T00:00:00.000' AS DateTime), 42, 35, 12, 118)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (152, 8, CAST(N'2024-02-22T00:00:00.000' AS DateTime), CAST(N'2023-06-03T00:00:00.000' AS DateTime), CAST(N'2023-11-03T00:00:00.000' AS DateTime), CAST(N'2024-05-03T00:00:00.000' AS DateTime), 46, 14, 50, 77)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (153, 8, CAST(N'2023-12-10T00:00:00.000' AS DateTime), CAST(N'2023-11-06T00:00:00.000' AS DateTime), CAST(N'2023-11-01T00:00:00.000' AS DateTime), CAST(N'2023-12-03T00:00:00.000' AS DateTime), 10, 43, 26, 14)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (154, 10, CAST(N'2024-05-14T00:00:00.000' AS DateTime), CAST(N'2023-07-06T00:00:00.000' AS DateTime), CAST(N'2024-05-29T00:00:00.000' AS DateTime), CAST(N'2024-03-06T00:00:00.000' AS DateTime), 42, 31, 18, 35)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (155, 10, CAST(N'2023-10-23T00:00:00.000' AS DateTime), CAST(N'2024-01-20T00:00:00.000' AS DateTime), CAST(N'2024-01-06T00:00:00.000' AS DateTime), CAST(N'2023-12-31T00:00:00.000' AS DateTime), 24, 23, 9, 46)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (156, 6, CAST(N'2023-08-04T00:00:00.000' AS DateTime), CAST(N'2023-11-13T00:00:00.000' AS DateTime), CAST(N'2023-08-05T00:00:00.000' AS DateTime), CAST(N'2023-10-01T00:00:00.000' AS DateTime), 28, 27, 49, 2)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (157, 9, CAST(N'2023-09-08T00:00:00.000' AS DateTime), CAST(N'2023-09-04T00:00:00.000' AS DateTime), CAST(N'2023-11-24T00:00:00.000' AS DateTime), CAST(N'2023-06-22T00:00:00.000' AS DateTime), 23, 18, 3, 215)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (158, 7, CAST(N'2024-02-15T00:00:00.000' AS DateTime), CAST(N'2023-09-28T00:00:00.000' AS DateTime), CAST(N'2023-08-30T00:00:00.000' AS DateTime), CAST(N'2023-09-13T00:00:00.000' AS DateTime), 8, 15, 8, 90)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (159, 7, CAST(N'2023-10-07T00:00:00.000' AS DateTime), CAST(N'2023-06-05T00:00:00.000' AS DateTime), CAST(N'2024-03-12T00:00:00.000' AS DateTime), CAST(N'2023-10-19T00:00:00.000' AS DateTime), 50, 48, 6, 230)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (160, 3, CAST(N'2023-10-20T00:00:00.000' AS DateTime), CAST(N'2023-07-31T00:00:00.000' AS DateTime), CAST(N'2023-07-05T00:00:00.000' AS DateTime), CAST(N'2023-10-08T00:00:00.000' AS DateTime), 39, 48, 50, 241)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (161, 3, CAST(N'2024-04-29T00:00:00.000' AS DateTime), CAST(N'2023-12-12T00:00:00.000' AS DateTime), CAST(N'2024-05-04T00:00:00.000' AS DateTime), CAST(N'2023-12-16T00:00:00.000' AS DateTime), 17, 49, 15, 212)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (162, 5, CAST(N'2023-11-11T00:00:00.000' AS DateTime), CAST(N'2023-06-28T00:00:00.000' AS DateTime), CAST(N'2024-05-02T00:00:00.000' AS DateTime), CAST(N'2023-08-22T00:00:00.000' AS DateTime), 40, 49, 10, 93)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (163, 9, CAST(N'2024-05-22T00:00:00.000' AS DateTime), CAST(N'2024-05-01T00:00:00.000' AS DateTime), CAST(N'2024-03-19T00:00:00.000' AS DateTime), CAST(N'2024-05-09T00:00:00.000' AS DateTime), 43, 35, 9, 302)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (164, 8, CAST(N'2023-08-16T00:00:00.000' AS DateTime), CAST(N'2023-11-06T00:00:00.000' AS DateTime), CAST(N'2023-07-11T00:00:00.000' AS DateTime), CAST(N'2023-06-13T00:00:00.000' AS DateTime), 27, 33, 21, 62)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (165, 10, CAST(N'2024-03-20T00:00:00.000' AS DateTime), CAST(N'2023-07-22T00:00:00.000' AS DateTime), CAST(N'2023-06-07T00:00:00.000' AS DateTime), CAST(N'2023-12-27T00:00:00.000' AS DateTime), 27, 44, 26, 236)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (166, 1, CAST(N'2023-06-11T00:00:00.000' AS DateTime), CAST(N'2023-12-15T00:00:00.000' AS DateTime), CAST(N'2023-06-24T00:00:00.000' AS DateTime), CAST(N'2023-12-02T00:00:00.000' AS DateTime), 48, 41, 45, 128)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (167, 4, CAST(N'2024-03-17T00:00:00.000' AS DateTime), CAST(N'2024-03-09T00:00:00.000' AS DateTime), CAST(N'2024-01-24T00:00:00.000' AS DateTime), CAST(N'2023-11-21T00:00:00.000' AS DateTime), 17, 16, 31, 14)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (168, 8, CAST(N'2023-10-31T00:00:00.000' AS DateTime), CAST(N'2023-07-14T00:00:00.000' AS DateTime), CAST(N'2024-02-22T00:00:00.000' AS DateTime), CAST(N'2023-12-10T00:00:00.000' AS DateTime), 25, 35, 21, 133)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (169, 10, CAST(N'2024-03-16T00:00:00.000' AS DateTime), CAST(N'2023-07-11T00:00:00.000' AS DateTime), CAST(N'2023-08-01T00:00:00.000' AS DateTime), CAST(N'2024-05-11T00:00:00.000' AS DateTime), 37, 31, 25, 218)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (170, 4, CAST(N'2024-04-04T00:00:00.000' AS DateTime), CAST(N'2023-07-20T00:00:00.000' AS DateTime), CAST(N'2023-11-22T00:00:00.000' AS DateTime), CAST(N'2023-07-06T00:00:00.000' AS DateTime), 19, 47, 29, 101)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (171, 8, CAST(N'2023-10-08T00:00:00.000' AS DateTime), CAST(N'2023-08-18T00:00:00.000' AS DateTime), CAST(N'2024-05-06T00:00:00.000' AS DateTime), CAST(N'2023-10-04T00:00:00.000' AS DateTime), 35, 16, 10, 362)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (172, 3, CAST(N'2023-07-01T00:00:00.000' AS DateTime), CAST(N'2024-05-20T00:00:00.000' AS DateTime), CAST(N'2024-01-06T00:00:00.000' AS DateTime), CAST(N'2024-02-29T00:00:00.000' AS DateTime), 25, 7, 25, 32)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (173, 9, CAST(N'2024-05-21T00:00:00.000' AS DateTime), CAST(N'2023-07-24T00:00:00.000' AS DateTime), CAST(N'2024-03-16T00:00:00.000' AS DateTime), CAST(N'2023-10-24T00:00:00.000' AS DateTime), 30, 10, 10, 278)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (174, 1, CAST(N'2023-11-05T00:00:00.000' AS DateTime), CAST(N'2024-01-28T00:00:00.000' AS DateTime), CAST(N'2024-02-12T00:00:00.000' AS DateTime), CAST(N'2024-04-10T00:00:00.000' AS DateTime), 29, 25, 14, 336)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (175, 7, CAST(N'2024-05-11T00:00:00.000' AS DateTime), CAST(N'2024-02-11T00:00:00.000' AS DateTime), CAST(N'2023-12-06T00:00:00.000' AS DateTime), CAST(N'2024-02-07T00:00:00.000' AS DateTime), 29, 39, 12, 305)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (176, 4, CAST(N'2023-12-23T00:00:00.000' AS DateTime), CAST(N'2023-06-29T00:00:00.000' AS DateTime), CAST(N'2023-09-01T00:00:00.000' AS DateTime), CAST(N'2023-09-19T00:00:00.000' AS DateTime), 21, 42, 41, 143)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (177, 3, CAST(N'2023-07-02T00:00:00.000' AS DateTime), CAST(N'2023-06-08T00:00:00.000' AS DateTime), CAST(N'2023-12-05T00:00:00.000' AS DateTime), CAST(N'2023-11-21T00:00:00.000' AS DateTime), 10, 23, 5, 181)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (178, 1, CAST(N'2023-06-13T00:00:00.000' AS DateTime), CAST(N'2024-03-23T00:00:00.000' AS DateTime), CAST(N'2024-05-12T00:00:00.000' AS DateTime), CAST(N'2024-01-19T00:00:00.000' AS DateTime), 12, 50, 10, 115)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (179, 7, CAST(N'2023-09-19T00:00:00.000' AS DateTime), CAST(N'2023-12-20T00:00:00.000' AS DateTime), CAST(N'2023-12-26T00:00:00.000' AS DateTime), CAST(N'2024-05-25T00:00:00.000' AS DateTime), 32, 32, 12, 334)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (180, 1, CAST(N'2023-08-20T00:00:00.000' AS DateTime), CAST(N'2023-06-13T00:00:00.000' AS DateTime), CAST(N'2024-02-25T00:00:00.000' AS DateTime), CAST(N'2024-01-14T00:00:00.000' AS DateTime), 40, 7, 9, 372)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (181, 5, CAST(N'2023-07-07T00:00:00.000' AS DateTime), CAST(N'2023-06-20T00:00:00.000' AS DateTime), CAST(N'2024-04-18T00:00:00.000' AS DateTime), CAST(N'2023-12-26T00:00:00.000' AS DateTime), 14, 50, 6, 38)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (182, 8, CAST(N'2023-07-13T00:00:00.000' AS DateTime), CAST(N'2023-06-07T00:00:00.000' AS DateTime), CAST(N'2024-04-17T00:00:00.000' AS DateTime), CAST(N'2024-04-22T00:00:00.000' AS DateTime), 15, 26, 49, 374)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (183, 1, CAST(N'2023-07-02T00:00:00.000' AS DateTime), CAST(N'2023-12-05T00:00:00.000' AS DateTime), CAST(N'2024-04-12T00:00:00.000' AS DateTime), CAST(N'2023-12-04T00:00:00.000' AS DateTime), 41, 12, 47, 286)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (184, 8, CAST(N'2023-12-01T00:00:00.000' AS DateTime), CAST(N'2023-12-27T00:00:00.000' AS DateTime), CAST(N'2023-06-10T00:00:00.000' AS DateTime), CAST(N'2023-10-04T00:00:00.000' AS DateTime), 2, 45, 17, 308)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (185, 3, CAST(N'2024-04-11T00:00:00.000' AS DateTime), CAST(N'2023-08-24T00:00:00.000' AS DateTime), CAST(N'2023-08-06T00:00:00.000' AS DateTime), CAST(N'2023-06-27T00:00:00.000' AS DateTime), 36, 44, 16, 220)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (186, 6, CAST(N'2024-02-07T00:00:00.000' AS DateTime), CAST(N'2023-09-16T00:00:00.000' AS DateTime), CAST(N'2024-03-14T00:00:00.000' AS DateTime), CAST(N'2023-11-05T00:00:00.000' AS DateTime), 45, 40, 21, 393)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (187, 9, CAST(N'2023-09-11T00:00:00.000' AS DateTime), CAST(N'2023-11-21T00:00:00.000' AS DateTime), CAST(N'2023-11-05T00:00:00.000' AS DateTime), CAST(N'2023-06-24T00:00:00.000' AS DateTime), 43, 27, 10, 100)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (188, 7, CAST(N'2023-11-05T00:00:00.000' AS DateTime), CAST(N'2024-03-21T00:00:00.000' AS DateTime), CAST(N'2024-02-07T00:00:00.000' AS DateTime), CAST(N'2024-05-12T00:00:00.000' AS DateTime), 41, 8, 22, 41)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (189, 1, CAST(N'2023-07-27T00:00:00.000' AS DateTime), CAST(N'2023-11-01T00:00:00.000' AS DateTime), CAST(N'2024-05-17T00:00:00.000' AS DateTime), CAST(N'2023-08-25T00:00:00.000' AS DateTime), 7, 4, 48, 294)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (190, 8, CAST(N'2023-10-31T00:00:00.000' AS DateTime), CAST(N'2023-08-11T00:00:00.000' AS DateTime), CAST(N'2023-11-04T00:00:00.000' AS DateTime), CAST(N'2024-04-15T00:00:00.000' AS DateTime), 9, 31, 18, 357)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (191, 6, CAST(N'2024-02-22T00:00:00.000' AS DateTime), CAST(N'2023-10-24T00:00:00.000' AS DateTime), CAST(N'2023-07-01T00:00:00.000' AS DateTime), CAST(N'2023-06-11T00:00:00.000' AS DateTime), 40, 35, 17, 94)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (192, 8, CAST(N'2023-10-07T00:00:00.000' AS DateTime), CAST(N'2024-05-10T00:00:00.000' AS DateTime), CAST(N'2023-12-30T00:00:00.000' AS DateTime), CAST(N'2023-06-14T00:00:00.000' AS DateTime), 20, 1, 24, 347)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (193, 7, CAST(N'2024-03-05T00:00:00.000' AS DateTime), CAST(N'2023-07-14T00:00:00.000' AS DateTime), CAST(N'2024-04-23T00:00:00.000' AS DateTime), CAST(N'2024-05-08T00:00:00.000' AS DateTime), 1, 47, 50, 49)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (194, 8, CAST(N'2023-09-11T00:00:00.000' AS DateTime), CAST(N'2023-07-18T00:00:00.000' AS DateTime), CAST(N'2023-12-19T00:00:00.000' AS DateTime), CAST(N'2024-03-05T00:00:00.000' AS DateTime), 20, 7, 9, 321)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (195, 3, CAST(N'2023-09-20T00:00:00.000' AS DateTime), CAST(N'2024-02-12T00:00:00.000' AS DateTime), CAST(N'2024-04-16T00:00:00.000' AS DateTime), CAST(N'2024-02-07T00:00:00.000' AS DateTime), 11, 48, 28, 317)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (196, 3, CAST(N'2023-09-15T00:00:00.000' AS DateTime), CAST(N'2023-12-31T00:00:00.000' AS DateTime), CAST(N'2023-08-22T00:00:00.000' AS DateTime), CAST(N'2023-11-01T00:00:00.000' AS DateTime), 28, 48, 47, 192)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (197, 9, CAST(N'2024-03-03T00:00:00.000' AS DateTime), CAST(N'2024-04-07T00:00:00.000' AS DateTime), CAST(N'2023-06-14T00:00:00.000' AS DateTime), CAST(N'2023-08-24T00:00:00.000' AS DateTime), 2, 9, 41, 357)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (198, 3, CAST(N'2024-02-15T00:00:00.000' AS DateTime), CAST(N'2023-12-26T00:00:00.000' AS DateTime), CAST(N'2024-02-03T00:00:00.000' AS DateTime), CAST(N'2023-11-25T00:00:00.000' AS DateTime), 32, 44, 8, 381)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (199, 2, CAST(N'2023-11-23T00:00:00.000' AS DateTime), CAST(N'2024-02-15T00:00:00.000' AS DateTime), CAST(N'2023-12-16T00:00:00.000' AS DateTime), CAST(N'2024-02-20T00:00:00.000' AS DateTime), 43, 4, 35, 261)
INSERT [dbo].[OrdenFabricacion] ([ldOrden], [idPlanta], [FechaHoraInicioplan], [FechaHoraFinPlan], [FechaHoraInicioReal], [FechaHoraFinReal], [idArticulo], [cantidadPlanificada], [cantidadRealizada], [legajoEmpleadoResponsable]) VALUES (200, 4, CAST(N'2024-04-26T00:00:00.000' AS DateTime), CAST(N'2023-09-04T00:00:00.000' AS DateTime), CAST(N'2023-07-25T00:00:00.000' AS DateTime), CAST(N'2024-01-14T00:00:00.000' AS DateTime), 20, 37, 42, 87)
GO

-- %% [markdown]
-- # [dbo].[PlantaFabricacion]

-- %%
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (1, N'Sand Palafox', N'6 Vahlen Crossing', N'2152')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (2, N'Roundleaf Waterlily', N'7302 Emmet Parkway', N'2490')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (3, N'Crabgrass', N'37 Milwaukee Pass', N'2586')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (4, N'Awnless Leastdaisy', N'5 Briar Crest Center', N'2328')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (5, N'Inyo Meadow Lupine', N'2 Eagle Crest Drive', N'2860')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (6, N'Allamanda', N'240 Forest Dale Way', N'2067')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (7, N'Dock Center', N'954 Weeping Birch Road', N'2414')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (8, N'Rocky Mountain Indian Parsley', N'07733 Fairview Center', N'2277')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (9, N'Menzies'' Burnet', N'5 Lunder Crossing', N'2699')
INSERT [dbo].[PlantaFabricacion] ([idPlanta], [nombre], [direccion], [codigopostal]) VALUES (10, N'Grand Merisier', N'62 Fremont Place', N'2764')
GO

-- %% [markdown]
-- # [dbo].[RecetaProduccion]

-- %%
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (1, 1, 22)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (1, 3, 36)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (1, 8, 3)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (1, 14, 34)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (1, 15, 38)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (1, 18, 27)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (2, 2, 8)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (2, 7, 42)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (2, 13, 35)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 4, 35)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 5, 13)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 10, 42)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 11, 21)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 15, 9)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 16, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 18, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (3, 19, 1)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (4, 3, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (4, 4, 11)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (4, 19, 25)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (5, 7, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (5, 9, 12)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (6, 11, 20)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (6, 17, 24)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (7, 4, 46)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (7, 9, 21)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (7, 11, 9)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (7, 12, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (7, 16, 28)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (7, 20, 16)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (8, 2, 28)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (8, 3, 43)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (8, 4, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (8, 8, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (8, 10, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 1, 43)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 3, 15)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 4, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 5, 46)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 9, 34)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 10, 21)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 11, 46)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 16, 31)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (9, 18, 4)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (10, 9, 9)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (10, 12, 6)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (10, 16, 45)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (10, 17, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (10, 19, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (10, 20, 26)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (11, 5, 38)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (11, 10, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (11, 16, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (12, 4, 6)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (12, 10, 34)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (12, 11, 50)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (12, 12, 19)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (12, 16, 13)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (12, 20, 38)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (13, 13, 22)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (14, 8, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (14, 10, 11)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (14, 13, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (14, 17, 35)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (15, 2, 46)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (15, 8, 6)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (15, 9, 4)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (15, 13, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (15, 14, 21)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (15, 15, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (15, 17, 36)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (16, 3, 34)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (16, 5, 20)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (16, 7, 1)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (16, 13, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (16, 14, 35)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (16, 16, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (17, 5, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (17, 8, 41)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (17, 9, 5)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (17, 13, 50)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (17, 14, 27)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (17, 17, 19)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (18, 1, 12)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (18, 5, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (18, 7, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (18, 8, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (18, 11, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (19, 1, 25)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (19, 5, 8)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (19, 8, 28)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (19, 10, 27)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (19, 11, 8)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (20, 1, 33)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (20, 10, 22)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (21, 8, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (21, 9, 2)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (21, 16, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (22, 5, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (22, 11, 18)
GO

-- %%
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (22, 12, 14)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (22, 13, 27)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (22, 14, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (22, 16, 43)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (22, 17, 27)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (23, 6, 31)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (23, 15, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (23, 16, 5)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (23, 19, 16)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (23, 20, 3)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 1, 37)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 2, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 6, 47)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 10, 41)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 11, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 12, 24)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 13, 20)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 14, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 15, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 18, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (24, 20, 20)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (25, 4, 42)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (25, 6, 24)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (25, 7, 34)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (25, 8, 16)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (25, 14, 33)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (25, 20, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (26, 7, 41)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (26, 9, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (26, 12, 19)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (26, 13, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (26, 18, 1)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (27, 3, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (27, 13, 43)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (27, 17, 15)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (27, 19, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (28, 2, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (28, 5, 19)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (28, 7, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (28, 9, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (28, 12, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (28, 19, 7)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (29, 2, 18)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (29, 4, 2)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (29, 9, 38)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (29, 13, 16)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (29, 18, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (30, 4, 26)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (30, 15, 7)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (30, 17, 12)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (30, 19, 25)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (31, 13, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (31, 15, 41)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (31, 16, 42)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (31, 20, 44)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (32, 3, 37)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (32, 7, 19)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (32, 10, 41)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (32, 13, 41)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (32, 15, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (32, 18, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (32, 19, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (33, 7, 35)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (33, 11, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (33, 17, 28)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 1, 1)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 3, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 8, 11)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 9, 8)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 10, 14)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 14, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 17, 24)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (34, 20, 8)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (35, 1, 45)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (35, 8, 11)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (35, 9, 19)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (35, 13, 13)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (35, 16, 22)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (35, 18, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (36, 6, 22)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (36, 7, 36)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (36, 9, 46)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (36, 11, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (36, 13, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (37, 3, 16)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (37, 7, 15)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (37, 11, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (37, 17, 38)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (37, 18, 14)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (38, 3, 12)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (38, 4, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (38, 9, 1)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (38, 12, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (38, 15, 23)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (38, 20, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 1, 18)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 6, 21)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 7, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 8, 44)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 11, 4)
GO

-- %%
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 18, 42)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 19, 27)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (39, 20, 14)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (40, 5, 31)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (40, 10, 4)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (40, 11, 47)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (41, 4, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (41, 7, 32)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (41, 14, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (41, 16, 35)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (41, 18, 8)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 1, 40)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 4, 4)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 6, 13)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 10, 35)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 11, 24)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 12, 16)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 13, 47)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (42, 16, 46)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 2, 41)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 9, 44)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 10, 29)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 11, 21)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 12, 38)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 15, 20)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 17, 15)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (43, 20, 20)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (44, 14, 45)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (44, 15, 15)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (45, 2, 32)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (45, 5, 30)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (45, 6, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (45, 11, 45)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (45, 12, 18)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (45, 17, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (45, 20, 6)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (46, 2, 43)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (46, 5, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (46, 8, 39)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (46, 10, 10)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (46, 15, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (46, 20, 13)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (47, 8, 12)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (47, 16, 34)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (47, 18, 3)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (48, 8, 17)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (48, 9, 1)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (48, 10, 8)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (48, 13, 31)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (48, 16, 48)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (48, 19, 5)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (49, 12, 42)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (49, 13, 49)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (49, 15, 15)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (49, 19, 18)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (50, 2, 42)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (50, 4, 5)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (50, 6, 12)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (50, 7, 1)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (50, 11, 17)
INSERT [dbo].[RecetaProduccion] ([IdArticulo], [idMateriaPrima], [Cantidad]) VALUES (50, 17, 14)
GO

-- %% [markdown]
-- # [FK_OrdenFabricacion_Articulo]

-- %%
ALTER TABLE [dbo].[OrdenFabricacion]  WITH CHECK ADD  CONSTRAINT [FK_OrdenFabricacion_Articulo] FOREIGN KEY([idArticulo])
REFERENCES [dbo].[Articulo] ([idArticulo])
GO
ALTER TABLE [dbo].[OrdenFabricacion] CHECK CONSTRAINT [FK_OrdenFabricacion_Articulo]
GO

-- %% [markdown]
-- # [FK_OrdenFabricacion_PlantaFabricacion]

-- %%
ALTER TABLE [dbo].[OrdenFabricacion]  WITH CHECK ADD  CONSTRAINT [FK_OrdenFabricacion_PlantaFabricacion] FOREIGN KEY([idPlanta])
REFERENCES [dbo].[PlantaFabricacion] ([idPlanta])
GO
ALTER TABLE [dbo].[OrdenFabricacion] CHECK CONSTRAINT [FK_OrdenFabricacion_PlantaFabricacion]
GO

-- %% [markdown]
-- # [FK_RecetaProduccion_Articulo]

-- %%
ALTER TABLE [dbo].[RecetaProduccion]  WITH CHECK ADD  CONSTRAINT [FK_RecetaProduccion_Articulo] FOREIGN KEY([IdArticulo])
REFERENCES [dbo].[Articulo] ([idArticulo])
GO
ALTER TABLE [dbo].[RecetaProduccion] CHECK CONSTRAINT [FK_RecetaProduccion_Articulo]
GO

-- %% [markdown]
-- # [FK_RecetaProduccion_MateriaPrima]

-- %%
ALTER TABLE [dbo].[RecetaProduccion]  WITH CHECK ADD  CONSTRAINT [FK_RecetaProduccion_MateriaPrima] FOREIGN KEY([idMateriaPrima])
REFERENCES [dbo].[MateriaPrima] ([idMateriaPrima])
GO
ALTER TABLE [dbo].[RecetaProduccion] CHECK CONSTRAINT [FK_RecetaProduccion_MateriaPrima]
GO
